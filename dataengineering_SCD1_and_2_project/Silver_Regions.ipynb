# %%
df = spark.sql('select * from databricksreddy.bronze.regions')

# %%
df= df.drop("_rescued_data")

# %%
df.write.format('delta')\
        .mode('overwrite')\
        .option('path','abfss://silver@datalakevishnu1.dfs.core.windows.net/regions')\
        .save()

# %%
df.write.mode('overwrite').saveAsTable('databricksreddy.silver.regions')
